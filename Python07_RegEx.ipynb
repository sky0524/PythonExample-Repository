# %%
import re
txt = "The rain in Spain"
x = re.search("^The.*Spain$", txt)

# %%
import re
txt = "The rain in Spain"
x = re.findall("ai", txt)
print(x)
# Out:
# ['ai', 'ai']

# %%
import re
txt = "The rain in Spain"
x = re.findall("Portugal", txt)
print(x)
# Out:
# []

# %%
import re
txt = "The rain in Spain"
x = re.search("\\s", txt)
print("The first white-space character is located in position:", x.start())
# Out:
# The first white-space character is located in position: 3

# %%
import re
txt = "The rain in Spain"
x = re.search("Portugal", txt)
print(x)
# Out:
# None

# %%
import re
txt = "The rain in Spain"
x = re.split("\\s", txt)
print(x)
# Out:
# ['The', 'rain', 'in', 'Spain']

# %%
import re
txt = "The rain in Spain"
x = re.split("\\s", txt, 1)
print(x)
# Out:
# ['The', 'rain in Spain']
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_51104\1696798333.py:3: DeprecationWarning: 'maxsplit' is passed as positional argument
#   x = re.split("\\s", txt, 1)

# %%
import re
txt = "The rain in Spain"
x = re.sub("\\s", "9", txt)
print(x)
# Out:
# The9rain9in9Spain

# %%
import re
txt = "The rain in Spain"
x = re.sub("\\s", "9", txt, 2)
print(x)
# Out:
# The9rain9in Spain
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_51104\3324233594.py:3: DeprecationWarning: 'count' is passed as positional argument
#   x = re.sub("\\s", "9", txt, 2)

# %%
import re
txt = "The rain in Spain"
x = re.search("ai", txt)
print(x)
# Out:
# <re.Match object; span=(5, 7), match='ai'>
