# %%
f = open("demofile.txt")
print(f.read())

# %%
with open(r"C:\Users\user\Desktop\2026_4_1\공유대학\Python programming\과제\welcome.txt", "r", encoding="utf-8") as f:
    print(f.read())

# %%
with open("demofile.txt") as f:
    print(f.read())

# %%
f = open("demofile.txt")
print(f.readline())
f.close()

# %%
with open("demofile.txt") as f:
    print(f.read(5))

# %%
with open("demofile.txt") as f:
    print(f.readline())
